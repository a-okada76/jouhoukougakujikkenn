# %% [markdown]
# # 実験 II 演習
#
# 言語処理 100 本ノックの「第 1 章: 準備運動」で言語処理の
# 基本的な前処理手法に慣れる．

# %% [markdown]
# # 00. 文字列の逆順
# 文字列”stressed”の文字を逆に（末尾から先頭に向かって）並べた文字列を得よ．

# %%
a = ("stressed")
print(a)
print(a[::-1])
# Out:
# stressed
# desserts

# %% [markdown]
# # 01. 「パタトクカシーー」
# 「パタトクカシーー」という文字列の1,3,5,7文字目を取り出して連結した文字列を得よ．

# %%
a = ("パタトクカシーー")
b, c, d, e = a[0], a[2], a[4], a[6]
f = b + c + d + e
print(f)
# Out:
# パトカー

# %% [markdown]
# # 02. 「パトカー」＋「タクシー」＝「パタトクカシーー」
# 「パトカー」＋「タクシー」の文字を先頭から交互に連結して文字列「パタトクカシーー」を得よ．

# %%
a = ("パトカー")
b = ("タクシー")

c = a[0] + b[0] + a[1] + b[1] + a[2] + b[2] + a[3] + b[3]

print(c)
# Out:
# パタトクカシーー

# %% [markdown]
# # 03. 円周率
# “Now I need a drink, alcoholic of course, after the heavy lectures involving quantum mechanics.”という文を単語に分解し，各単語の（アルファベットの）文字数を先頭から出現順に並べたリストを作成せよ．

# %%
a = ("Now I need a drink, alcoholic of course, after the heavy lectures involving quantum mechanics.")
b = a.split()
#print(b)
c = []
for i in range(len(b)):
    if b[i][-1] != ',' and b[i][-1] != '.':
        c.append(len(b[i]))
    else:
        c.append(len(b[i]) - 1)
        
print(c)
# Out:
# [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5, 8, 9, 7, 9]

# %% [markdown]
# # 04. 元素記号
# “Hi He Lied Because Boron Could Not Oxidize Fluorine. New Nations Might Also Sign Peace Security Clause. Arthur King Can.”という文を単語に分解し，1, 5, 6, 7, 8, 9, 15, 16, 19番目の単語は先頭の1文字，それ以外の単語は先頭の2文字を取り出し，取り出した文字列から単語の位置（先頭から何番目の単語か）への連想配列（辞書型もしくはマップ型）を作成せよ．

# %%
a = ("Hi He Lied Because Boron Could Not Oxidize Fluorine. New Nations Might Also Sign Peace Security Clause. Arthur King Can.")
b = a.split()
#print(b)
c = []

for i in range(len(b)):
    if i==0 or i==4 or i==5 or i==6 or i==7 or i==8 or i==14 or i==15 or i==18:
        c.append(b[i][0])
    else:
        c.append(b[i][0] + b[i][1])

#print(c)    

d = {}
for i in range(len(c)):
    d[c[i]] = i+1

print(d)
# Out:
# {'H': 1, 'He': 2, 'Li': 3, 'Be': 4, 'B': 5, 'C': 6, 'N': 7, 'O': 8, 'F': 9, 'Ne': 10, 'Na': 11, 'Mi': 12, 'Al': 13, 'Si': 14, 'P': 15, 'S': 16, 'Cl': 17, 'Ar': 18, 'K': 19, 'Ca': 20}

# %% [markdown]
# # 05. n-gram
# 与えられたシーケンス（文字列やリストなど）からn-gramを作る関数を作成せよ．この関数を用い，”I am an NLPer”という文から単語bi-gram，文字bi-gramを得よ．
#
#
# n-gram とは n 個のデータの連接である．
# 1-gram, 2-gram, 3-gram, ..., n-gram となる．
# 一般に 1-gram, 2-gram, 3-gram をそれぞれ uni-gram, bi-gram, tri-gram と書く．
# それぞれ「ユニグラム」，「バイグラム」，「トライグラム」と読む．
# 単語 n-gram は単語を単位とした連接，文字 n-gram は文字を単位とした連接である．
# "I saw a girl with a telescope." という文があったとしたら，
# 単語 uni-gram は "I", "saw", "a",...,"telescope."，
# 文字 uni-gram は "I", " ", "s", "a", "w",...,"."，
# 単語 bi-gram は "I saw", "saw a", "a girl",..., "a telescope."，
# 文字 bi-gram は "I ", " s", "sa", "aw", "w ", " a",...,"e."
# となる．

# %%
import re
def n_gram(n, a):
    b = a.split()
    c = []
    d = ('')
    for i in range(len(b) - n + 1):
        for j in range(i, n + i):
            d += b[j]
            if j != n + i -1:
                d += ' '
        c.append(d)
        d = ('')

    
    b = list(a)
    e = []
    d = ('')
    for i in range(len(b) - n + 1):
        for j in range(i, n + i):
            d += b[j]
        e.append(d)
        d = ('')
        
    return c, e

a = ("I am an NLPer")
tango, moji = n_gram(2, a)
print("単語bi-gram")
print(tango)
print("文字bi-gram")
print(moji)
# Out:
# 単語bi-gram
# ['I am', 'am an', 'an NLPer']
# 文字bi-gram
# ['I ', ' a', 'am', 'm ', ' a', 'an', 'n ', ' N', 'NL', 'LP', 'Pe', 'er']

# %% [markdown]
# # 06. 集合
# “paraparaparadise”と”paragraph”に含まれる文字bi-gramの集合を，それぞれ, XとYとして求め，XとYの和集合，積集合，差集合を求めよ．さらに，’se’というbi-gramがXおよびYに含まれるかどうかを調べよ．

# %%
def onajimoji(gram, a):
    for i in range(len(a)):
        if gram == a[i]:
            return True
    return False        
    

a = ("paraparaparadise")
b = ("paragraph")

x, X_gram = n_gram(2, a)
y, Y_gram = n_gram(2, b)

X = []
Y = []
for i in range(len(X_gram)):
    if onajimoji(X_gram[i], X) == False:
        X.append(X_gram[i])

for i in range(len(Y_gram)):
    if onajimoji(Y_gram[i], Y) == False:
        Y.append(Y_gram[i]) 

print("X = {}".format(X))
print("Y = {}".format(Y))

wa = X.copy()
seki = []
sa = X.copy()
flag = True

for i in range(len(Y)):
    if onajimoji(Y[i], wa) == False:
        wa.append(Y[i])

print("wa = {}".format(wa))   

for i in range(len(Y)):
    if onajimoji(Y[i], X) == True:
        seki.append(Y[i])

print("seki = {}".format(seki))            

for i in range(len(Y)):
    if onajimoji(Y[i], X) == True:
        sa.remove(Y[i])                   

print("sa = {}".format(sa))
# Out:
# X = ['pa', 'ar', 'ra', 'ap', 'ad', 'di', 'is', 'se']
# Y = ['pa', 'ar', 'ra', 'ag', 'gr', 'ap', 'ph']
# wa = ['pa', 'ar', 'ra', 'ap', 'ad', 'di', 'is', 'se', 'ag', 'gr', 'ph']
# seki = ['pa', 'ar', 'ra', 'ap']
# sa = ['ad', 'di', 'is', 'se']

# %% [markdown]
# # 07. テンプレートによる文生成
# 引数x, y, zを受け取り「x時のyはz」という文字列を返す関数を実装せよ．さらに，x=12, y=”気温”, z=22.4として，実行結果を確認せよ．

# %%
def make_sent(x, y, z):
    a = ("{}時の{}は{}".format(x, y, z))
    return a

a = make_sent(12, "気温", 22.4)
print(a)
# Out:
# 12時の気温は22.4

# %% [markdown]
# # 08. 暗号文
# 与えられた文字列の各文字を，以下の仕様で変換する関数cipherを実装せよ．
#
# 英小文字ならば(219 - 文字コード)の文字に置換
# その他の文字はそのまま出力
# この関数を用い，英語のメッセージを暗号化・復号化せよ．

# %%
def cipher(a):
    a = list(a)
    for i in range(len(a)):
        if a[i].islower():
            b = 219 - ord(a[i])
            a[i] = chr(b)
    c = "".join(a)        
    return c

a = ("I am an NLPer")   
print(cipher(a))
# Out:
# I zn zm NLPvi

# %% [markdown]
# # 09. Typoglycemia
# スペースで区切られた単語列に対して，各単語の先頭と末尾の文字は残し，それ以外の文字の順序をランダムに並び替えるプログラムを作成せよ．ただし，長さが４以下の単語は並び替えないこととする．適当な英語の文（例えば”I couldn’t believe that I could actually understand what I was reading : the phenomenal power of the human mind .”）を与え，その実行結果を確認せよ．

# %%
import random
a = ("I couldn’t believe that I could actually understand what I was reading : the phenomenal power of the human mind .")
b = a.split()
print(a)

for i in range(len(b)):
    if len(b[i]) > 4:
        c = ''
        for j in range(1, len(b[i]) - 1):
            c += b[i][j]
        cr = ''.join(random.sample(c, len(c)))    
        b[i] = b[i][0] + cr + b[i][-1]

#print(b)
d = ''
for i in range(len(b)):
    d += b[i]
    if i != len(b) - 1:
        d += ' '

print(d)
# Out:
# I couldn’t believe that I could actually understand what I was reading : the phenomenal power of the human mind .
# I cuodln’t bileeve that I colud aaulctly uadnertsnd what I was readnig : the peamonehnl peowr of the haumn mind .
